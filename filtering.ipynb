# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('top_podcasts.csv')
df.head(5)
# Out:
#          date  rank region chartRankMove              episodeUri  \
# 0  2024-09-02     1     us     UNCHANGED  37kBZRr3nqjltQXt8KuiDJ
# 1  2024-09-02     2     us     UNCHANGED  293KKxbEKt2zrem6XFCxYG
# 2  2024-09-02     3     us     UNCHANGED  53z4LvgoGjjVkdiJkCGhZX
# 3  2024-09-02     4     us            UP  5rrRkpfKZUUR85WxMYCX9k
# 4  2024-09-02     5     us          DOWN  2Qd2dJDDAocbTjGvXwHOfm
#
#                   showUri                                        episodeName  \
# 0  4rOoJ6Egrf8K2IrywzwOMk                                 #2197 - Mike Baker
# 1  4rOoJ6Egrf8K2IrywzwOMk                            #2195 - Andrew Huberman
# 2  4rOoJ6Egrf8K2IrywzwOMk                           #2196 - Greg Fitzsimmons
# 3  0KvuZJgXfOGanBRuq6B9dm  The Worst Creature To Run Into During The Ice Age
# 4  5L2ON33kXa2b7laBpCAgOI  Jeffrey Sachs: Trump’s Plan to Stop WWIII, CIA...
#
#                                          description  \
# 0  Mike Baker is a former CIA covert operations o...
# 1  Andrew Huberman, PhD, is a neuroscientist and ...
# 2  Greg Fitzsimmons is a comedian, actor, and wri...
# 3  The Ice Age was no doubt one of earth’s most q...
# 4  Professor Jeffrey Sachs’s provides a full and ...
#
#                   show.name  \
# 0  The Joe Rogan Experience
# 1  The Joe Rogan Experience
# 2  The Joe Rogan Experience
# 3                ExtinctZoo
# 4   The Tucker Carlson Show
#
#                                     show.description  ... show.copyrights  \
# 0        The official podcast of comedian Joe Rogan.  ...              []
# 1        The official podcast of comedian Joe Rogan.  ...              []
# 2        The official podcast of comedian Joe Rogan.  ...              []
# 3  Your one stop shop for all things dinosaurs, p...  ...              []
# 4  The Tucker Carlson Show is your beacon of free...  ...              []
#
#    show.explicit                                          show.href  \
# 0           True  https://api.spotify.com/v1/shows/4rOoJ6Egrf8K2...
# 1           True  https://api.spotify.com/v1/shows/4rOoJ6Egrf8K2...
# 2           True  https://api.spotify.com/v1/shows/4rOoJ6Egrf8K2...
# 3          False  https://api.spotify.com/v1/shows/0KvuZJgXfOGan...
# 4          False  https://api.spotify.com/v1/shows/5L2ON33kXa2b7...
#
#                                show.html_description  \
# 0  <p>The official podcast of comedian Joe Rogan....
# 1  <p>The official podcast of comedian Joe Rogan....
# 2  <p>The official podcast of comedian Joe Rogan....
# 3  Your one stop shop for all things dinosaurs, p...
# 4  <p>The Tucker Carlson Show is your beacon of f...
#
#    show.is_externally_hosted show.languages show.media_type  \
# 0                      False         ['en']           mixed
# 1                      False         ['en']           mixed
# 2                      False         ['en']           mixed
# 3                      False         ['en']           mixed
# 4                      False         ['en']           audio
#
#   show.total_episodes show.type                             show.uri
# 0                2366      show  spotify:show:4rOoJ6Egrf8K2IrywzwOMk
# 1                2366      show  spotify:show:4rOoJ6Egrf8K2IrywzwOMk
# 2                2366      show  spotify:show:4rOoJ6Egrf8K2IrywzwOMk
# 3                  30      show  spotify:show:0KvuZJgXfOGanBRuq6B9dm
# 4                 115      show  spotify:show:5L2ON33kXa2b7laBpCAgOI
#
# [5 rows x 29 columns]

# %%
df = df[(df['region'] == 'us') | (df['region'] == 'gb') | (df['region'] == 'au')]
df.head(5)
# Out:
#          date  rank region chartRankMove              episodeUri  \
# 0  2024-09-02     1     us     UNCHANGED  37kBZRr3nqjltQXt8KuiDJ
# 1  2024-09-02     2     us     UNCHANGED  293KKxbEKt2zrem6XFCxYG
# 2  2024-09-02     3     us     UNCHANGED  53z4LvgoGjjVkdiJkCGhZX
# 3  2024-09-02     4     us            UP  5rrRkpfKZUUR85WxMYCX9k
# 4  2024-09-02     5     us          DOWN  2Qd2dJDDAocbTjGvXwHOfm
#
#                   showUri                                        episodeName  \
# 0  4rOoJ6Egrf8K2IrywzwOMk                                 #2197 - Mike Baker
# 1  4rOoJ6Egrf8K2IrywzwOMk                            #2195 - Andrew Huberman
# 2  4rOoJ6Egrf8K2IrywzwOMk                           #2196 - Greg Fitzsimmons
# 3  0KvuZJgXfOGanBRuq6B9dm  The Worst Creature To Run Into During The Ice Age
# 4  5L2ON33kXa2b7laBpCAgOI  Jeffrey Sachs: Trump’s Plan to Stop WWIII, CIA...
#
#                                          description  \
# 0  Mike Baker is a former CIA covert operations o...
# 1  Andrew Huberman, PhD, is a neuroscientist and ...
# 2  Greg Fitzsimmons is a comedian, actor, and wri...
# 3  The Ice Age was no doubt one of earth’s most q...
# 4  Professor Jeffrey Sachs’s provides a full and ...
#
#                   show.name  \
# 0  The Joe Rogan Experience
# 1  The Joe Rogan Experience
# 2  The Joe Rogan Experience
# 3                ExtinctZoo
# 4   The Tucker Carlson Show
#
#                                     show.description  ... show.copyrights  \
# 0        The official podcast of comedian Joe Rogan.  ...              []
# 1        The official podcast of comedian Joe Rogan.  ...              []
# 2        The official podcast of comedian Joe Rogan.  ...              []
# 3  Your one stop shop for all things dinosaurs, p...  ...              []
# 4  The Tucker Carlson Show is your beacon of free...  ...              []
#
#    show.explicit                                          show.href  \
# 0           True  https://api.spotify.com/v1/shows/4rOoJ6Egrf8K2...
# 1           True  https://api.spotify.com/v1/shows/4rOoJ6Egrf8K2...
# 2           True  https://api.spotify.com/v1/shows/4rOoJ6Egrf8K2...
# 3          False  https://api.spotify.com/v1/shows/0KvuZJgXfOGan...
# 4          False  https://api.spotify.com/v1/shows/5L2ON33kXa2b7...
#
#                                show.html_description  \
# 0  <p>The official podcast of comedian Joe Rogan....
# 1  <p>The official podcast of comedian Joe Rogan....
# 2  <p>The official podcast of comedian Joe Rogan....
# 3  Your one stop shop for all things dinosaurs, p...
# 4  <p>The Tucker Carlson Show is your beacon of f...
#
#    show.is_externally_hosted show.languages show.media_type  \
# 0                      False         ['en']           mixed
# 1                      False         ['en']           mixed
# 2                      False         ['en']           mixed
# 3                      False         ['en']           mixed
# 4                      False         ['en']           audio
#
#   show.total_episodes show.type                             show.uri
# 0                2366      show  spotify:show:4rOoJ6Egrf8K2IrywzwOMk
# 1                2366      show  spotify:show:4rOoJ6Egrf8K2IrywzwOMk
# 2                2366      show  spotify:show:4rOoJ6Egrf8K2IrywzwOMk
# 3                  30      show  spotify:show:0KvuZJgXfOGanBRuq6B9dm
# 4                 115      show  spotify:show:5L2ON33kXa2b7laBpCAgOI
#
# [5 rows x 29 columns]

# %%
df.to_csv('episodes.csv', index=False)
